# %% [markdown]
# # Modelo de lenguaje con ngramas

# %% [markdown]
# ## Instalación de dependencias

# %%
# !pip install regex

# %%
# !pip install gdown

# %%
# !pip install wikipedia-api

# %% [markdown]
# ## Descarga de corpus

# %% [markdown]
# ### Chat de WhatsApp

# %%
# !gdown --id 1HNenXhn8KVwMIHeyQigkOGT837U1zwS3
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1HNenXhn8KVwMIHeyQigkOGT837U1zwS3
# To: /content/whatsapp.txt
# 100% 4.44M/4.44M [00:00<00:00, 158MB/s]

# %%
with open("/content/whatsapp.txt", "r", encoding="utf-8-sig") as f:
    chat = f.read()

# %% [markdown]
# ## Textos propios

# %% [markdown]
# #### Ciencias de la Computación

# %%
# !gdown --id 1ayUSN7PNCp6Bed1B2sP8PSnXQOevCALq
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1ayUSN7PNCp6Bed1B2sP8PSnXQOevCALq
# To: /content/ciencias_de_la_computación.txt
# 100% 14.5k/14.5k [00:00<00:00, 28.1MB/s]

# %%
with open("/content/ciencias_de_la_computación.txt", "r", encoding="latin1") as f:
    text1 = f.read()

# %% [markdown]
# #### Inteligencia artificial

# %%
# !gdown --id 1WqyFs4_hpsJXXkw-US4fIuEzVRkxkd3h
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1WqyFs4_hpsJXXkw-US4fIuEzVRkxkd3h
# To: /content/inteligencia_artificial.txt
# 100% 3.08k/3.08k [00:00<00:00, 7.73MB/s]

# %%
with open("/content/inteligencia_artificial.txt", "r", encoding="latin1") as f:
    text2 = f.read()

# %% [markdown]
# #### Redes de computadoras

# %%
# !gdown --id 12ZdznxWF5VVKnIw-jWmcaccJyQGqWYhx
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=12ZdznxWF5VVKnIw-jWmcaccJyQGqWYhx
# To: /content/redes_de_computadoras.txt
# 100% 2.01k/2.01k [00:00<00:00, 6.32MB/s]

# %%
with open("/content/redes_de_computadoras.txt", "r", encoding="latin1") as f:
    text3 = f.read()

# %% [markdown]
# ## Wikipedia

# %% [markdown]
# Utilizamos la api de wikipedia en español para conseguir los textos

# %%
import wikipediaapi

USER_AGENT = "ngrams"
en_wiki = wikipediaapi.Wikipedia(USER_AGENT, language='en')
es_wiki = wikipediaapi.Wikipedia(USER_AGENT, language='es')

# %%
import re

# %% [markdown]
# Función para limpiar los textos de caracteres extraños, o líneas incongruentes

# %%
import re
import unicodedata

def limpiar_texto(texto):
    # Remover entidades HTML como
    texto = re.sub(r'&[a-z]+;', ' ', texto)

    # Remover 'px' (pixeles)
    texto = re.sub(r'\d*\.?\d+\s*px', ' ', texto)
    texto = re.sub(r'px', ' ', texto)

    # Remover letras griegas (alfabeto griego completo)
    # Rango Unicode para letras griegas: U+0370 a U+03FF
    texto = ''.join(char if not ('\u0370' <= char <= '\u03FF') else ' ' for char in texto)

    # Remover símbolos matemáticos y científicos comunes
    texto = re.sub(r'[°±×÷√∞≈≠≤≥]', ' ', texto)

    # Remover puntuación y caracteres especiales
    # Mantener solo letras, espacios y algunos caracteres básicos
    texto = re.sub(r'[^\w\sáéíóúñüàèìòùâêîôûäëïöü]', ' ', texto)

    # Remover guiones bajos
    texto = re.sub(r'_+', ' ', texto)

    # Remover caracteres de control y formato
    texto = ''.join(char for char in texto if unicodedata.category(char)[0] != 'C')

    # Normalizar espacios múltiples a uno solo
    texto = re.sub(r'\s+', ' ', texto)

    return texto

# %% [markdown]
# ### Primer artículo: Procesamiento de lenguaje natural

# %%
tema = "procesamiento de lenguaje natural"
page = es_wiki.page(tema)
if page.exists():
    article1 = page.text
    article1 = limpiar_texto(article1)


print(article1)
# Out:
# El procesamiento de l lenguaje natural o de lengua je s naturales abreviado PLN o NLP por sus siglas en inglés es un campo de las ciencias de la computación de la inteligencia artificial y de la lingüística que estudia las interacciones entre las computadoras y el lenguaje humano así como los detalles computacionales de las lenguas naturales Se ocupa de la formulación e investigación de mecanismos eficaces computacionalmente para la comunicación entre personas y máquinas por medio del lenguaje natural es decir de las lenguas del mundo No trata de la comunicación por medio de lenguas naturales de una forma abstracta sino de diseñar mecanismos para comunicarse que sean eficaces computacionalmente que se puedan realizar por medio de programas que ejecuten o simulen la comunicación Los modelos aplicados se enfocan no solo a la comprensión del lenguaje de por sí sino a aspectos generales cognitivos humanos y a la organización de la memoria El lenguaje natural sirve solo de medio para estu
# ...

# %%
num_palabras = len(article1.split())
print(num_palabras)
# Out:
# 1252

# %% [markdown]
# ### Segundo artículo: Modelo de lenguaje

# %%
tema = "modelo de lenguaje"
page = es_wiki.page(tema)
if page.exists():
    article2 = page.text
    article2 = limpiar_texto(article2)

print(article2)
# Out:
# Modelación del lenguaje hace referencia a la tarea de predecir la siguiente palabra o carácter en un documento Esta técnica puede ser usada para entrenar modelos de lenguaje con una gran diversidad de aplicaciones como la generación de texto o la clasificación de textos entre otras Esto se realiza por medio de información estadística asociada con un vocabulario específico que tiene el objetivo de predecir las palabras con más probabilidades de ser utilizadas Contar con una forma de estimar la verosimilitud de diversas frases resulta sumamente útil en una variedad de aplicaciones dentro del procesamiento del lenguaje natural Los modelos de lenguaje se emplean en el reconocimiento de voz la traducción automática el etiquetado de discurso el análisis de texto el reconocimiento de escritura la recuperación de información y otras muchas aplicaciones EjemplosEn el reconocimiento de voz la computadora se esfuerza por asociar los sonidos con secuencias de palabras El modelo de lenguaje desem
# ...

# %% [markdown]
# ### Tercer artículo: Ciencias de la computación

# %%
tema = "ciencias de la computación"
page = es_wiki.page(tema)
if page.exists():
    article3 = page.text
    article3 = limpiar_texto(article3)

print(article3)
# Out:
# Las ciencias de la computación también denominadas ciencias de la informática son un conjunto de ciencias formales que estudian los fundamentos teóricos de la información y de la computación así como sus aplicaciones prácticas en los sistemas de información y en los sistemas informáticos El cuerpo de conocimiento de las ciencias de la computación suele describirse como el estudio sistemático de los procesos algorítmicos que describen transforman y representan información su teoría análisis diseño eficiencia implementación y aplicación En un sentido más específico la disciplina aborda el estudio formal de la factibilidad la estructura la expresión y la automatización de procedimientos metódicos o algoritmos que intervienen en la adquisición representación procesamiento almacenamiento comunicación y acceso a la información La información puede estar codificada en forma de bits dentro de la memoria de una computadora o representada en otros sistemas físicos o biológicos como los genes y
# ...

# %% [markdown]
# ##Chat de WhatsApp

# %%
mensajes = re.split(r'\n(?=\d{1,2}/\d{1,2}/\d{2,4},)', chat)

mensajes_limpios = []

for mensaje in mensajes:
    if not re.search(r'- .*?:', mensaje):
      continue
    #Limpiamos mensajes automáticos de whatsapp
    # ej. se fijó un mensaje
    if re.search(r'fijó un mensaje|se unió|salió|cambió|Cambió|añadió|OPCIÓN:|quitó|Se eliminó este mensaje.', mensaje):
      continue

    limpio = re.sub(r'^\d{1,2}/\d{1,2}/\d{2,4},\s.*?\s-\s.*?:\s','',mensaje)
    #Quitamos personas que han sido etiquetadas (información personal)
    limpio = re.sub(r'@\S+', '', limpio)
    #Quitamos links
    limpio = re.sub(r'(?i)(https?://\S+|www\.\S+)', '', limpio)
    #Quitamos números de telefono
    limpio = re.sub(r'\b66\d{8}\b', '', limpio)
    limpio = re.sub(r'\b\d{3}\s\d{3}\s\d{4}\b', '', limpio)
    #Descartamos asteriscos (Usados para poner texto en negrita)
    limpio = re.sub(r'\*', '', limpio)
    #Quitamos mensajes de Whatsapp
    limpio = re.sub(r'<.*?>', '', limpio)


    if "<Multimedia omitido>" not in limpio:
        mensajes_limpios.append(limpio.strip())

chat_final = " ".join(mensajes_limpios)

print(chat_final)
# Out:
#  Hagan su cuenta Me dijo mi compa que no es necesario ir todos los dias Al tec Con que se vaya el día de la presentación Pero si queremos ir     Nomamen Mejor el sábado aquí en la uni Compramos comida entre todos Yya vamos el domingo   Pero el dia de la presentación es el viernes qno? El domingo Nomames El viernes empieza Nice El domingo nos vamos al Tec saliendo de la Uni Cómo q el domingo Viernes El domingo mo abre la uni we El viernes nos vamos de la uni, el sábado nos quedamos aquí en la uni y el domingo si vamos  Viernes Q les parece y si mejor rentamos un hotel a lado del tec  Este bato Nomames Como hay muchos hoteles en la carretera un airbnb aca Rompemos una ventana de la uvm Te va a salir una vaca Te lo digo por experiencia Me va a salir uno bato que no alcanzo a entrar al tec JSJAJAJAJAJAJAJA JAJAJAJJAJAJAJAJAJAAJJAJAJAJJA bueno pues ideas buenas Propongan  Hacemos el del mapa .  Ese nomas es acomodar la info pa que quede bonito Me parece  Cómo nos vamos a quedar en la Uní 
# ...

# %% [markdown]
# ## Corpus

# %%
corpus = chat_final + " " + text1 + " " + text2 + " " + text3 + " " + article1 + " " + article2 + " " + article3

# %%
import regex as re

corpus = re.sub(r"\\u[0-9a-fA-F]{4}|\\U[0-9a-fA-F]{8}", "", corpus)
corpus = re.sub(r"[^\p{L}\p{N}\s]", "", corpus)
corpus = re.sub(r"\s+", " ", corpus).strip()

# %%
corpus_lower = corpus.lower()

# %% [markdown]
# ## Creamos el modelo de lenguaje

# %%
import nltk
from nltk import bigrams, trigrams
nltk.download('punkt_tab')

def crear_modelo_trigrama(texto):
    # Tokenizar
    palabras = nltk.word_tokenize(texto, language='spanish')

    # Crear trigramas
    trigramas = []
    for i in range(len(palabras) - 2):
        trigramas.append((palabras[i], palabras[i+1], palabras[i+2]))

    # Alternativamente, crear trigramas con nltk
    # trigramas = list(trigrams(palabras))

    # Contar
    conteos = {}
    for w1, w2, w3 in trigramas:
        if (w1, w2) not in conteos:
            conteos[(w1, w2)] = {}
        if w3 not in conteos[(w1, w2)]:
            conteos[(w1, w2)][w3] = 0
        conteos[(w1, w2)][w3] += 1

    # Convertir a probabilidades
    modelo = {}
    for par, terceras in conteos.items():
        total = sum(terceras.values())
        modelo[par] = {palabra: cuenta/total for palabra, cuenta in terceras.items()}

    return modelo
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Entrenamos el modelo con los corpus

# %%
modelo = crear_modelo_trigrama(corpus)

print(f"\nModelo entrenado con {len(modelo)} pares de palabras únicos")
# Out:
# Modelo entrenado con 138623 pares de palabras únicos

# %%
modelo_lower = crear_modelo_trigrama(corpus_lower)

print(f"\nModelo entrenado con {len(modelo_lower)} pares de palabras únicos")
# Out:
# Modelo entrenado con 124262 pares de palabras únicos

# %%
modelo
# Out:
# {('Hagan', 'su'): {'cuenta': 0.5, 'carta': 0.5},
#  ('su', 'cuenta'): {'Me': 0.16666666666666666,
#   'puede': 0.16666666666666666,
#   'la': 0.16666666666666666,
#   'Tenía': 0.16666666666666666,
#   'PQ': 0.16666666666666666,
#   'cree': 0.16666666666666666},
#  ('cuenta', 'Me'): {'dijo': 1.0},
#  ('Me', 'dijo'): {'mi': 0.19047619047619047,
#   'un': 0.047619047619047616,
#   'el': 0.23809523809523808,
#   'que': 0.23809523809523808,
#   'q': 0.14285714285714285,
#   'muchas': 0.047619047619047616,
#   'a': 0.047619047619047616,
#   'Que': 0.047619047619047616},
#  ('dijo', 'mi'): {'compa': 0.125,
#   'ama': 0.125,
#   'jefe': 0.125,
#   'mamá': 0.125,
#   'apa': 0.125,
#   'amiga': 0.25,
#   'mama': 0.125},
#  ('mi', 'compa'): {'que': 0.3333333333333333,
#   'javi': 0.08333333333333333,
#   'con': 0.08333333333333333,
#   'vive': 0.08333333333333333,
#   'bien': 0.08333333333333333,
#   'danGPT': 0.08333333333333333,
#   'Pura': 0.08333333333333333,
# ...

# %%
def predecir_siguiente(palabra1, palabra2, modelo):
    """
    Predice la siguiente palabra más probable.

    Args:
        palabra1: Primera palabra del contexto
        palabra2: Segunda palabra del contexto
        modelo: Diccionario con probabilidades

    Returns:
        La palabra más probable, o None si no hay predicción
    """
    par = (palabra1, palabra2)

    # Verificar si conocemos este par de palabras
    if par not in modelo:
        return None

    # Obtener la palabra con mayor probabilidad
    probabilidades = modelo[par]
    palabra_mas_probable = max(probabilidades, key=probabilidades.get)

    return palabra_mas_probable

def generar_texto(palabra_inicial1, palabra_inicial2, modelo, longitud=10):
    """
    Genera texto palabra por palabra usando el modelo.

    Args:
        palabra_inicial1: Primera palabra para empezar
        palabra_inicial2: Segunda palabra para empezar
        modelo: Modelo de n-gramas
        longitud: Cuántas palabras generar

    Returns:
        Texto generado como string
    """
    # Empezar con las dos palabras iniciales
    texto_generado = [palabra_inicial1, palabra_inicial2]

    for _ in range(longitud):
        # Usar las últimas dos palabras para predecir la siguiente
        w1 = texto_generado[-2]
        w2 = texto_generado[-1]

        siguiente = predecir_siguiente(w1, w2, modelo)

        # Si no hay predicción, terminar
        if siguiente is None:
            break

        texto_generado.append(siguiente)

    return ' '.join(texto_generado)

# %%
# Palabras de inicio:
inicio11, inicio21 = "ayer", "fue"
inicio12, inicio22 = "al", "caffenio"
inicio13, inicio23 = "el", "cc"
inicio14, inicio24 = "donde", "andan"
inicio15, inicio25 = "vamos", "a"

longitud1 = 50
longitud2 = 60
longitud3 = 75
longitud4 = 80
longitud5 = 100

texto_generado1 = generar_texto(inicio11, inicio21, modelo, longitud=longitud1)
print(f"Comenzando con '{inicio11} {inicio21}':\n\t{texto_generado1}")

texto_generado_lower1 = generar_texto(inicio11, inicio21, modelo_lower, longitud=longitud1)
print(f"Comenzando con '{inicio11} {inicio21}':\n\t{texto_generado_lower1}")


print(f'\n\n{50*"-"}\n\n')


texto_generado2 = generar_texto(inicio12, inicio22, modelo, longitud=longitud2)
print(f"Comenzando con '{inicio12} {inicio22}':\n\t{texto_generado2}")

texto_generado_lower2 = generar_texto(inicio12, inicio22, modelo_lower, longitud=longitud2)
print(f"Comenzando con '{inicio12} {inicio22}':\n\t{texto_generado_lower2}")


print(f'\n\n{50*"-"}\n\n')


texto_generado3 = generar_texto(inicio13, inicio23, modelo, longitud=longitud3)
print(f"Comenzando con '{inicio13} {inicio23}':\n\t{texto_generado3}")

texto_generado_lower3 = generar_texto(inicio13, inicio23, modelo_lower, longitud=longitud3)
print(f"Comenzando con '{inicio13} {inicio23}':\n\t{texto_generado_lower3}")


print(f'\n\n{50*"-"}\n\n')


texto_generado4 = generar_texto(inicio14, inicio24, modelo, longitud=longitud4)
print(f"Comenzando con '{inicio14} {inicio24}':\n\t{texto_generado4}")

texto_generado_lower4 = generar_texto(inicio14, inicio24, modelo_lower, longitud=longitud4)
print(f"Comenzando con '{inicio14} {inicio24}':\n\t{texto_generado_lower4}")


print(f'\n\n{50*"-"}\n\n')


texto_generado5 = generar_texto(inicio15, inicio25, modelo, longitud=longitud5)
print(f"Comenzando con '{inicio15} {inicio25}':\n\t{texto_generado5}")

texto_generado_lower5 = generar_texto(inicio15, inicio25, modelo_lower, longitud=longitud5)
print(f"Comenzando con '{inicio15} {inicio25}':\n\t{texto_generado_lower5}")
# Out:
# Comenzando con 'ayer fue':
# 	ayer fue el que está en el cc No hay clase de historia ya subió la tarea de Irene en sábado Na Tampoco estén chingando JAJAJAA no me acuerdo de eso es un nombre muy descriptivo pero que no se me hace que va a ser el conductor del autobús me regañó
# Comenzando con 'ayer fue':
# 	ayer fue el que no se me hace que va a ser el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo
#
#
# --------------------------------------------------
#
#
# Comenzando con 'al caffenio':
# 	al caffenio de medicina Quiero café y no me acuerdo de eso es un nombre muy descriptivo pero que no se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a
# Comenzando con 'al caffenio':
# ...

# %% [markdown]
# # Análisis y comparación

# %% [markdown]
# ## a) Estadísticas del modelo

# %% [markdown]
#  ### Número total de n-gramas únicos generados

# %%
print(f"\nLower: OFF - Modelo entrenado con {len(modelo)} pares de palabras únicos")

print(f"\nLower: ON - Modelo entrenado con {len(modelo_lower)} pares de palabras únicos")
# Out:
# Lower: OFF - Modelo entrenado con 138623 pares de palabras únicos
#
# Lower: ON - Modelo entrenado con 124262 pares de palabras únicos

# %% [markdown]
# ### Tamaño del vocabulario (palabras únicas)

# %%
palabras = corpus.split()
palabras_unicas = set(palabras)

print(f"\nLower: OFF - Tamaño del vocabulario: {len(palabras_unicas)}")

palabras = corpus_lower.split()
palabras_unicas = set(palabras)

print(f"\nLower: ON - Tamaño del vocabulario: {len(palabras_unicas)}")
# Out:
# Lower: OFF - Tamaño del vocabulario: 23677
#
# Lower: ON - Tamaño del vocabulario: 19786

# %% [markdown]
# ### Top 10 n-gramas únicos generados

# %%
tri = [texto_generado1, texto_generado2, texto_generado3, texto_generado4, texto_generado5,
       texto_generado_lower1, texto_generado_lower2, texto_generado_lower3, texto_generado_lower4, texto_generado_lower5]
tri_compl = " ".join(tri)

# %%
modelo_frecuencia = crear_modelo_trigrama(tri_compl)

# %%
todos = []

for (w1, w2), siguientes in modelo.items():
    for w3, prob in siguientes.items():
        todos.append(((w1, w2, w3), prob))

# ordenar
todos_ordenados = sorted(todos, key=lambda x: x[1], reverse=True)

for elemento in todos_ordenados[:10]:
    print(elemento)
# Out:
# (('cuenta', 'Me', 'dijo'), 1.0)
# (('necesario', 'ir', 'todos'), 1.0)
# (('dias', 'Al', 'tec'), 1.0)
# (('Al', 'tec', 'Con'), 1.0)
# (('tec', 'Con', 'que'), 1.0)
# (('presentación', 'Pero', 'si'), 1.0)
# (('ir', 'Nomamen', 'Mejor'), 1.0)
# (('Nomamen', 'Mejor', 'el'), 1.0)
# (('sábado', 'aquí', 'en'), 1.0)
# (('uni', 'Compramos', 'comida'), 1.0)

# %% [markdown]
# ## b) Calidad del texto generado

# %% [markdown]
# ### Presentación de los textos generados

# %% [markdown]
# #### Semilla 1
# <p> Palabras clave: <b>ayer fue</b>
# <p> Lowercase (OFF):
# <p>ayer fue el que está en el cc No hay clase de historia ya subió la tarea de Irene en sábado Na Tampoco estén chingando JAJAJAA no me acuerdo de eso es un nombre muy descriptivo pero que no se me hace que va a ser el conductor del autobús me regañó
#
# <p> Lowercase (ON):
# <p>ayer fue el que no se me hace que va a ser el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo

# %% [markdown]
# #### Semilla 2
# <p> Palabras clave: <b>al caffenio</b>
# <p> Lowercase (OFF):
# <p> al caffenio de medicina Quiero café y no me acuerdo de eso es un nombre muy descriptivo pero que no se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a
#
# <p> Lowercase (ON):
# <p> al caffenio de la computación y de ahí en fuera bien el semestre cuando el fernando empieza a las 11 de la computación y de ahí en fuera bien el semestre cuando el fernando empieza a las 11 de la computación y de ahí en fuera bien el semestre cuando el fernando empieza a las 11 de la computación y de ahí

# %% [markdown]
# #### Semilla 3
# <p> Palabras clave: <b>el cc</b>
# <p> Lowercase (OFF):
# <p> el cc No hay clase de historia ya subió la tarea de Irene en sábado Na Tampoco estén chingando JAJAJAA no me acuerdo de eso es un nombre muy descriptivo pero que no se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el
#
# <p> Lowercase (ON):
# <p>	el cc no hay nadie en la uni y el fer y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea

# %% [markdown]
# #### Semilla 4
# <p> Palabras clave: <b>donde andan</b>
# <p> Lowercase (OFF):
# <p> donde andan En la noche para ver si me la creo como son Como que no se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me
#
# <p> Lowercase (ON):
# <p> donde andan en la uni y el fer y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el

# %% [markdown]
# #### Semilla 5
# <p> Palabras clave: <b>vamos a</b>
# <p> Lowercase (OFF):
# <p> vamos a ir a la uni no se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va a ser el conductor del autobús me regañó bien feo el horario y se me hace que va
#
# <p> Lowercase (ON):
# <p> vamos a ir a la uni y el fer y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no tengo ni idea de cómo es la misma cara que el javi y yo no

# %% [markdown]
# ### Evaluación subjetiva de coherencia (escala 1 - 5)

# %% [markdown]
# #### Semilla 1
# <p> Lowercase (OFF) 4/5
# <p> Lowercase (ON) 1/5

# %% [markdown]
# #### Semilla 2
# <p> Lowercase (OFF) 3/5
# <p> Lowercase (ON) 3/5

# %% [markdown]
# #### Semilla 3
# <p> Lowercase (OFF) 3/5
# <p> Lowercase (ON) 1/5

# %% [markdown]
# #### Semilla 4
# <p> Lowercase (OFF) 2/5
# <p> Lowercase (ON) 1/5

# %% [markdown]
# #### Semilla 5
# <p> Lowercase (OFF) 1/5
# <p> Lowercase (ON) 1/5

# %% [markdown]
# ### Identificar patrones interesantes

# %% [markdown]
# #### Patrones interesantes
# *   y yo no tengo ni idea de cómo es la misma cara que el javi
# *   y de ahí en fuera bien el semestre cuando el fernando empieza a las 11 de la computación
# *   y se me hace que va a ser el conductor del autobús me regañó bien feo el horario
# *   No hay clase de historia ya subió la tarea de Irene en sábado

# %% [markdown]
# ### Comparación ON vs OFF

# %% [markdown]
# #### ¿Cuál configuración genera texto más coherente?

# %% [markdown]
# El corpus con letras mayúsculas
# *   Los textos se sienten un poco más variados y menos repetitivos.
# *   Mantienen mejor el flujo de ideas, auqnue sea de forma simple.
# *   No se quedan tan rápido "atorados" en la misma frase.
# *   Las oraciones suenan más naturales y menos mecánicas.

# %% [markdown]
# #### ¿Cómo afecta la naturalidad del texto?

# %% [markdown]
# La naturalidad del texto es mayor con lowercase desactivado, ya que hay más variedad y menos repetición, mientras que con lowercase activado el texto se vuelve monótono y menos humano debido a la repetición constante.

# %% [markdown]
# ## Conclusión / Reflexión

# %% [markdown]
# El modelo es límitado, ya que al solo considerar las dos palabras anteriores no recibe el suficiente contexto para predecir de forma aceptable la siguiente palabra. Se vuelve redundante muy facilmente, ya que se repiten cadenas por patrones muy simples, lo cual puede ser común para texto no muy largos.
#
# Se pudiera mejorar eliminando la probabilidad de una palabra siguiente que sea 0, ya que eso limita la generación de texto, y también añadiendo más texto para mejorar las probabilidades
